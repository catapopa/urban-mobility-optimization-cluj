# %%
import osmnx as ox

G = ox.load_graphml("../data/processed/cluj_osm.graphml")
ox.plot_graph(G, bgcolor='white', node_size=3, edge_color='darkblue')
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
